# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
color_list = ['#60FAF8', '#97E3FE', '#F8FE29', '#92C2DD', '#F38E59', '#CC54D0', '#8B6A84', '#F394F8']
country_list = ['Ukraine', 'Russia', 'UK', 'India', 'Cambodia', 'China', 'Poland', 'Germany']
marker_list = ['o', 's', 'v', '^', '+', '*', '+', '+']

df = pd.read_csv('2022-2023 TOP 8 NATIONS.csv',sep=',', header=None)
df.columns = ['Term', 'Country', 'Value']

fig, ax = plt.subplots(figsize = (16, 9))

for i, country in enumerate(country_list):
   df_country = df[df['Country'] == country]
   ax.plot(df_country['Term'], df_country['Value'], label=country, color = color_list[i]
            , marker=marker_list[i], linewidth = 2.5)

# ax.set_title('Frequency change chart of national words in the fifth quarter', fontsize = 26)
ax.set_xlabel('Terms', fontsize = 20)
ax.set_ylabel('Counts', fontsize = 20)


# 显示图形
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
# 添加图例
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# 柱状图 snake 和 technology Terminology

# %%
new_color_list = ['#2843AD', '#9A53D0', '#818DE0', '#F394F8', '#97E3FE', '#244E30', '#4B713F', '#5BAB3C', '#C8F424', '#F8FE29']
x = ['Malware', 'Ransomware', 'Email', 'Software', 'Windows', 'Application', 'Website',
     'Google', 'Infrastructure', 'Business']
y = [3811,2415,1822,1597,1381,1190,1161,1068,984,975]

plt.figure(figsize=(16,9))
# 提取票房数据
plt.yticks(size = 20)
plt.xticks(range(0, int(max(y))+100, 300), size = 12)
# 设置y轴刻度范围，使坐标刻度从十四开始
plt.xlabel("Counts", loc='right', fontdict={"fontsize": 15})
# 设置坐标轴和图像标签
plt.barh(x, y, height=0.7, color = new_color_list)
plt.subplots_adjust(left=0.25, right=0.97, top=0.95, bottom=0.1) 
plt.show()

# %%
color_list = ['#60FAF8', '#97E3FE', '#F8FE29', '#92C2DD', '#F38E59', '#CC54D0', '#8B6A84', '#F394F8']
tech_list = ["Phishing", "Email(attack)", "Ransomware", "DDos", "Backdoor"]
marker_list = ['o', 's', 'v', '^', '+']

tech = pd.read_csv('2022-2023 TECH KEYWORDS.csv',sep=',', header=None)
tech.columns = ['Term', 'Keywords', 'Value']

fig, ax = plt.subplots(figsize = (16, 9))

for i, tech_i in enumerate(tech_list):
   df_tech = tech[tech['Keywords'] == tech_i]
   ax.plot(df_tech['Term'], df_tech['Value'], label=tech_i, color = color_list[i]
            , marker=marker_list[i], linewidth = 2.5)

# ax.set_title('Frequency change chart of national words in the fifth quarter', fontsize = 26)
ax.set_xlabel('Terms', fontsize = 20)
ax.set_ylabel('Counts', fontsize = 20)


# 显示图形
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
# 添加图例
plt.legend(fontsize=15)
plt.show()
