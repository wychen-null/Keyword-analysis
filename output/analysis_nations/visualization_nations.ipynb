# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
color_list = ['#45AAB4', '#206491', '#FEAAC2', '#FBB45C', '#F9637C', '#D6594C', '#81D0BB', '#FE7966']
country_list = ['Ukraine', 'Russia', 'UK', 'India', 'Cambodia', 'China', 'Poland', 'Germany']

df = pd.read_csv('2022-2023 TOP 8 NATIONS.csv',sep=',', header=None)
df.columns = ['Term', 'Country', 'Value']

fig_multiple, ax = plt.subplots()

                 </span><span style="color:#8c8c8c;font-style:italic;font-family:'宋体',monospace;">创建图形并分割为两个子图<br /></span>fig_multiple, ax = plt.subplots(<span style="color:#660099;">figsize </span>= (<span style="color:#1750eb;">25</span>,<span style="color:#1750eb;">14</span>))<br /><br /><span style="color:#0033b3;">for </span>i, country <span style="color:#0033b3;">in </span><span style="color:#000080;">enumerate</span>(country_list) :<br />   df_country = df[df[<span style="color:#067d17;">'Country'</span>] == country]<br />   ax.plot(df_country[<span style="color:#067d17;">'Term'</span>], df_country[<span style="color:#067d17;">'Value'</span>],<span style="color:#660099;">color </span>= color_list[i], <span style="color:#660099;">label</span>=country)<br /><br />ax.set_title(<span style="color:#067d17;">&quot;Frequency change chart of national words in the fifth quarter&quot;</span>)<br />ax.set_xlabel(<span style="color:#067d17;">'Term'</span>, <span style="color:#660099;">fontsize </span>= <span style="color:#1750eb;">20</span>)<br />ax.set_ylabel(<span style="color:#067d17;">'Count'</span>, <span style="color:#660099;">fontsize </span>= <span style="color:#1750eb;">20</span>)<br />plt.legend()<br />plt.show()</pre>
